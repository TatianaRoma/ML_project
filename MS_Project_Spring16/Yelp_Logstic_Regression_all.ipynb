# %%
### libraries
import numpy as np
import pandas as pd
import matplotlib as mpl

import matplotlib.pyplot as plt
# %matplotlib inline

from pylab import *
import itertools
import random
import scipy
import six
import re

from __future__ import print_function
from pprint import pprint
import time as time
import seaborn as sns
sns.set()

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.svm import SVC 
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.cross_validation import KFold
from sklearn.metrics import confusion_matrix, f1_score
from sklearn import metrics
from sklearn.cross_validation import train_test_split
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
path = r'/home/ubuntu/yelp/reviews_all.csv'
reviews = pd.read_csv(path)
reviews['Rating_nom'] = ["one" if Rating == 1 else "two" if Rating == 2 else "three" if Rating == 3 
                else "four" if Rating == 4 else "five" for Rating in reviews.Rating]
reviews = reviews[['Text','Rating_nom']]

# %%
labels = ["one","two","three","four","five"]

def plot_confusion(confmat):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(confmat)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
reviews_sample = reviews.sample(n = 100000)
pipeline = Pipeline([
    ('vectorizer',  CountVectorizer(stop_words='english')),
    ('transformer', TfidfTransformer()),
    ('lrClassifier',  LogisticRegression(multi_class='multinomial',solver='lbfgs')) ])

parameters = {
    'vectorizer__ngram_range': ((1,1),(1,2),(1,3)),
    'vectorizer__max_df': (0.6, 0.75),
    'vectorizer__min_df': (1000, 0.01, 0.1),
    'transformer__use_idf': (True, False),
    'lrClassifier__max_iter': (100, 200) 
}
        
if __name__ == "__main__":
    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1, verbose=10, cv=2)

    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)
    t0 = time.time()
    grid_search.fit(reviews_sample.Text.values, reviews_sample.Rating_nom.values)
    print("done in %0.3fs" % (time.time() - t0))
    print("Best score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# pipeline: ['vectorizer', 'transformer', 'lrClassifier']
# parameters:
# {'lrClassifier__max_iter': (100, 200),
#  'transformer__use_idf': (True, False),
#  'vectorizer__max_df': (0.6, 0.75),
#  'vectorizer__min_df': (1000, 0.01, 0.1),
#  'vectorizer__ngram_range': ((1, 1), (1, 2), (1, 3))}
# Fitting 2 folds for each of 72 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed: 28.0min finished
# done in 1779.961s
# Best score: 0.561
# Best parameters set:
# 	lrClassifier__max_iter: 200
# 	transformer__use_idf: True
# 	vectorizer__max_df: 0.6
# 	vectorizer__min_df: 0.01
# 	vectorizer__ngram_range: (1, 2)
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6
# [CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.536949 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.540811 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.537829 - 2.6min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.543211 - 2.6min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.537829 - 4.4min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.543211 - 4.5min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.557049 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.559511 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.559389 - 2.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.561771 - 2.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.559389 - 4.5min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.561771 - 4.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456711 - 1.3min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.454409 - 1.3min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456711 - 2.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.454409 - 2.6min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456711 - 4.2min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.454409 - 4.1min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.537829 - 4.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.543211 - 4.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456711 - 4.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.454409 - 4.5min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.536949 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.543211 - 2.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.559389 - 4.5min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.561771 - 2.5min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.537809 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.540271 - 1.2min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.540811 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.537829 - 2.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.559511 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.561771 - 4.4min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.558791 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.555989 - 1.4min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.457831 - 2.7min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456709 - 2.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.555989 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.558791 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.557049 - 1.3min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.454409 - 1.1min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456709 - 4.7min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.538069 - 4.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.559149 - 2.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.561031 - 2.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.559389 - 2.6min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456711 - 2.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.454409 - 2.4min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.457831 - 4.7min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.456709 - 1.3min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.457831 - 1.3min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.559149 - 4.9min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.561031 - 4.8min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.457831 - 2.6min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456709 - 2.6min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456711 - 1.1min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.542991 - 2.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.557169 - 1.8min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.457831 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.542991 - 4.7min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.538069 - 4.9min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.542991 - 4.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.561031 - 4.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.559149 - 4.9min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.542871 - 5.2min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.542991 - 2.8min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.538069 - 2.8min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.537329 - 1.6min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.537869 - 3.0min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.559909 - 5.2min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.561651 - 5.0min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.6, score=0.538069 - 2.6min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.540271 - 1.4min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.456791 - 2.7min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.537329 - 1.6min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.456791 - 1.2min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.454549 - 1.2min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456709 - 1.3min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.542871 - 3.1min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.537869 - 3.1min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.454549 - 1.2min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.456709 - 4.9min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.457831 - 4.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.561651 - 3.1min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.456791 - 2.6min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.537669 - 1.5min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.540771 - 1.5min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.537809 - 1.4min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.561031 - 2.9min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.559909 - 4.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.561651 - 3.2min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.540871 - 1.5min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.542871 - 3.0min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.540871 - 1.6min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.454549 - 4.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.456791 - 4.7min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.543211 - 2.8min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.542871 - 4.9min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.537869 - 5.0min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.559631 - 1.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.559549 - 4.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.559549 - 3.0min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.561591 - 3.0min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=100, vectorizer__max_df=0.75, score=0.559149 - 2.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.558911 - 1.8min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.537669 - 1.5min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.558911 - 1.8min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.559909 - 3.1min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.454549 - 2.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.559909 - 3.2min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.538269 - 4.9min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.543211 - 5.0min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.456569 - 4.5min
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.457911 - 1.1min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.457911 - 2.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.457911 - 4.5min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.456569 - 1.2min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.555989 - 1.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.559631 - 1.7min[CV]  vectorizer__min_df=1000, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.537869 - 5.2min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.454549 - 2.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.559549 - 3.0min[CV]  vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.454549 - 4.3min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.555989 - 1.6min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.561591 - 4.7min[CV]  vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.557169 - 1.8min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.457911 - 1.2min
#
#
#
#
#
#
#
#
#
#
#
#
#
# [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.01, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=True, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75 [CV] vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6
#
#
#
#
#
#
#
#
# [CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 2), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.543211 - 2.9min[CV]  vectorizer__min_df=0.01, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.559549 - 3.9min[CV]  vectorizer__min_df=0.1, transformer__use_idf=False, vectorizer__ngram_range=(1, 1), lrClassifier__max_iter=200, vectorizer__max_df=0.6, score=0.456569 - 1.1min[CV]  vectorizer__min_df=1000, transformer__use_idf=False, vectorizer__ngram_range=(1, 3), lrClassifier__max_iter=200, vectorizer__max_df=0.75, score=0.543211 - 4.4min

# %%
pipeline = Pipeline([
    ('vectorizer',  CountVectorizer(ngram_range=(1,2), stop_words='english',
                                   max_df=0.6, min_df=0.01)),
    ('transformer', TfidfTransformer(use_idf=True)),
    ('classifier',  LogisticRegression(multi_class='multinomial',solver='lbfgs', max_iter=200)) ])

k_fold = KFold(n=len(reviews), n_folds=3)
scores = []
confusion = np.zeros(shape=(5,5))
for train_indices, test_indices in k_fold:
    train_text = reviews.iloc[train_indices]['Text'].values
    train_y = reviews.iloc[train_indices]['Rating_nom'].values

    test_text = reviews.iloc[test_indices]['Text'].values
    test_y = reviews.iloc[test_indices]['Rating_nom'].values

    pipeline.fit(train_text, train_y)
    predictions = pipeline.predict(test_text)

    confusion += confusion_matrix(test_y, predictions, 
                                  labels = labels)
    print(metrics.classification_report(test_y, predictions, labels = labels))

print('Total reviews classified:', len(reviews))
#print('Score:', sum(scores)/len(scores))
print('Confusion matrix:')
print(confusion)
plot_confusion(confusion)
# Out:
#              precision    recall  f1-score   support
#
#         one       0.63      0.67      0.65     29184
#         two       0.46      0.36      0.40     32409
#       three       0.49      0.37      0.42     51230
#        four       0.53      0.59      0.56    106542
#        five       0.67      0.70      0.69    110844
#
# avg / total       0.57      0.58      0.57    330209
#
#              precision    recall  f1-score   support
#
#         one       0.63      0.66      0.65     29226
#         two       0.46      0.36      0.40     32474
#       three       0.48      0.37      0.42     51161
#        four       0.53      0.58      0.55    106666
#        five       0.67      0.71      0.69    110682
#
# avg / total       0.57      0.58      0.57    330209
#
#              precision    recall  f1-score   support
#
#         one       0.62      0.66      0.64     28803
#         two       0.47      0.36      0.41     32693
#       three       0.48      0.37      0.42     51231
#        four       0.53      0.59      0.55    106330
#        five       0.67      0.71      0.69    111152
#
# avg / total       0.57      0.58      0.57    330209
#
# Total reviews classified: 990627
# Confusion matrix:
# [[  57940.   15879.    4774.    5129.    3491.]
#  [  21058.   34888.   23696.   13393.    4541.]
#  [   6873.   17797.   56978.   60596.   11378.]
#  [   3694.    4725.   26927.  186713.   97479.]
#  [   3065.    1949.    5056.   87879.  234729.]]
