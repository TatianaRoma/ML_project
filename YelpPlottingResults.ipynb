# %%
import numpy as np
import pandas as pd
import matplotlib as mpl

import matplotlib.pyplot as plt
# %matplotlib inline
#%pylab inline

from pylab import *

# load statsmodels
import statsmodels.api as sm

import itertools

from sklearn import metrics

import random
import scipy
import six
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB


from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

import gc
import json
import re

# use seaborn plotting defaults
import sys
sys.path.append('/Users/tatiana/anaconda/pkgs/seaborn-0.6.0-np110py34_0/lib/python3.4/site-packages')
import seaborn as sns; sns.set()

# %%
import scipy as sc
import pylab as pl

# %%
path = r'/Users/tatiana/Desktop/DATA_ANALYTICS/yelp_wt.csv'
wt = pd.read_csv(path)
wt.head()
# Out:
#    funny  useful  cool contains(able) contains(absolutely) contains(across)  \
# 0      1       1     0          False                False            False
# 1      0       3     2          False                False            False
# 2      0       2     0          False                False            False
# 3      1       1     1          False                False            False
# 4      3       2     3          False                False            False
#
#   contains(actually) contains(add) contains(added) contains(ago)    ...     \
# 0              False         False           False         False    ...
# 1              False         False           False         False    ...
# 2              False         False           False         False    ...
# 3              False         False           False         False    ...
# 4              False         False           False         False    ...
#
#   contains(wow) contains(wrong) contains(year) contains(years) contains(yelp)  \
# 0         False            True          False           False          False
# 1         False           False          False           False          False
# 2         False           False          False           False          False
# 3         False           False          False           False          False
# 4         False           False          False           False          False
#
#   contains(yes) contains(yet) contains(yum) contains(yummy) stars_nom
# 0         False         False         False           False       one
# 1         False         False         False           False      four
# 2         False         False         False           False       one
# 3         False         False         False           False       two
# 4         False         False         False           False       two
#
# [5 rows x 735 columns]

# %%
y = wt[['stars_nom']].values.flatten()
X = wt.iloc[:,0:733].values

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=.4, random_state=1)

# %% [markdown]
# ###Logistic Regression

# %%
columns = ['KNN', 'LR', 'SVM','NB']
index = ['one','two','three','four','five']

precision = pd.DataFrame(columns=columns, index = index)
precision['KNN'] = [0.34,0.22,0.29,0.37,0.41]
precision['LR'] = [0.61,0.42,0.48,0.49,0.61]
precision['NB'] = [0.54,0.38,0.45,0.51,0.63]
precision['SVM'] = [0.58,0.39,0.47,0.50,0.63]
precision['blended'] = [0.8,0.42,0.49,0.52,0.73]

recall = pd.DataFrame(columns=columns, index = index)
recall['KNN'] = [0.28,0.04,0.08,0.33,0.71]
recall['LR'] = [0.60,0.25,0.31,0.53,0.74]
recall['NB'] = [0.63,0.28,0.38,0.48,0.73]
recall['SVM'] = [0.6,0.29,0.32,0.54,0.71]
recall['blended'] = [0.55,0.43,0.36,0.64,0.72]
precision
# Out:
#         KNN    LR   SVM    NB  blended
# one    0.34  0.61  0.58  0.54     0.80
# two    0.22  0.42  0.39  0.38     0.42
# three  0.29  0.48  0.47  0.45     0.49
# four   0.37  0.49  0.50  0.51     0.52
# five   0.41  0.61  0.63  0.63     0.73

# %%
recall
# Out:
#         KNN    LR   SVM    NB  blended
# one    0.28  0.60  0.60  0.63     0.55
# two    0.04  0.25  0.29  0.28     0.43
# three  0.08  0.31  0.32  0.38     0.36
# four   0.33  0.53  0.54  0.48     0.64
# five   0.71  0.74  0.71  0.73     0.72

# %%
plt.figure(); 
precision.plot(); 
plt.ylabel('Precision')
plt.xlabel('Review rating')
plt.title('Precision of classification for different algorithms')
plt.legend(loc='best')

# %%
plt.figure(); 
recall.plot();
plt.ylabel('Precision')
plt.xlabel('Review rating')
plt.title('Recall of classification for different algorithms')
plt.legend(loc='best')
